# %%
from diagnose import diagnose
from dataset_process import ZsRE
from models import llama, gptj, gpt2, bert, t5, qwen, chatglm2
from methods import SPINE

dataset = ZsRE.ZsREDataset(loc=ZsRE.default_loc)
sample = ZsRE.get_processed_kvs(dataset[0], SPINE.requires_input_keys)
result = diagnose.diagnosing(sample=sample, model_name_or_path=gptj, method=SPINE.name)

print(result)
# Out:
# module 'kv_template' has no attribute 'dataset_info'
# Loaded dataset with 1301 elements
# loading model: /root/autodl-fs/gpt-j-6b
# /root/autodl-fs/gpt-j-6b model loaded
# /root/interpret-lm/methods/SPINE/SPINE_main.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(embedding).to(dtype)
# {'origin_data': {'sample_tokens': ['Which', 'family', 'does', 'Ep', 'asp', 'id', 'oc', 'er', 'as', 'bel', 'ong', 'to', '?'], 'topk_embeddings': [[[14394, 0.0248936228454113], [2599, 0.02359713241457939], [12147, 0.02037506364285946], [12612, 0.019267119467258453], [266, 0.018567902967333794]], [[9306, 0.02369004487991333], [5382, 0.020812487229704857], [6688, 0.020790517330169678], [12734, 0.02024172618985176], [12612, 0.019829533994197845]], [[7650, 0.02128877118229866], [9306, 0.019137827679514885], [1340, 0.01763811707496643], [11215, 0.01727883517742157], [6648, 0.016728475689888]], [[1558, 0.030606500804424286], [11227, 0.02498730458319187], [11569, 0.0235431008040905], [11891, 0.022609893232584], [6925, 0.021983865648508072]], [[11546, 0.023635949939489365], [290, 0.021408984437584877], [12612, 0.02134624309837818], [7311, 0.020570656284689903], [15194, 0.02052094228565693]], [[3671, 0.021877534687519073], [15657, 0.021693002432584763], [10903, 0.01974576897919178], [15537, 0.01839280128479004], [9306, 0.01698237471282482]], [[7907, 0.028015129268169403], [461, 0.021291552111506462], [8688, 0.020245840772986412], [8120, 0.0197908878326416], [4622, 0.018138311803340912]], [[11156, 0.01683107018470764], [3588, 0.015434548258781433], [9306, 0.014395708218216896], [122, 0.012941734865307808], [12730, 0.012918572872877121]], [[11156, 0.019073858857154846], [10914, 0.017873380333185196], [6891, 0.01598465070128441], [3987, 0.015556653961539268], [5225, 0.015427476726472378]], [[13599, 0.030689897015690804], [5225, 0.025924691930413246], [15537, 0.022356780245900154], [7297, 0.022152289748191833], [12194, 0.022115478292107582]], [[12215, 0.019909609109163284], [6930, 0.019505921751260757], [11607, 0.01891777664422989], [1676, 0.017669212073087692], [7536, 0.01752379536628723]], [[1690, 0.025989705696702003], [11761, 0.017580587416887283], [5225, 0.01716362126171589], [11156, 0.017026595771312714], [4253, 0.015104985795915127]], [[3588, 0.016783935949206352], [10903, 0.01612667553126812], [4499, 0.014981383457779884], [9306, 0.014885337091982365], [1558, 0.013571360148489475]]]}, 'table': [{'table_name': ' token Which', 'table_list': [{'dimension': 14394, 'activation values': 0.0248936228454113, 'The tokens with the highest activation values in this dimension of the vocabulary': ['oooo', 'Ġadequate', '¢', "'m", 'ĠJerusalem']}, {'dimension': 2599, 'activation values': 0.02359713241457939, 'The tokens with the highest activation values in this dimension of the vocabulary': ['ĠStew', 'udeau', 'ĠChase', 'arr', 'Ġattach']}, {'dimension': 12147, 'activation values': 0.02037506364285946, 'The tokens with the highest activation values in this dimension of the vocabulary': ['ĠNex', 'Ġbrutal', 'ĠBloom', 'igious', 'Ġcontinuous']}, {'dimension': 12612, 'activation values': 0.019267119467258453, 'The tokens with the highest activation values in this dimension of the vocabulary': ['ĠMovement', 'Ġremove', 'Ġreports', 'Ġmom', 'Ġclouds']}, {'dimension': 266, 'activation values': 0.018567902967333794, 'The tokens with the highest activation values in this dimension of the vocabulary': ['anim', 'Ġâĸ', 'ĠNetwork', 'Ġlayout', 'âĢ']}], 'table_des': 'Each row represents one of the top-k activation values along with its corresponding dimensional index and the several words from the vocabulary that have the highest activation values in this dimension', 'table_res': ''}, {'table_name': ' token family', 'table_list': [{'dimension': 9306, 'activation values': 0.02369004487991333, 'The tokens with the highest activation values in this dimension of the vocabulary': ['Ġimag', 'Ġassemb', 'ĠKal', 'Ġpushed', 'ĠMovement']}, {'dimension': 5382, 'activation values': 0.020812487229704857, 'The tokens with the highest activation values in this dimension of the vocabulary': ['Ġremarkable', 'ĠStock', 'Ġmemor', 'Ġcelebrated', 'ĠKal']}, {'dimension': 6688, 'activation values': 0.020790517330169678, 'The tokens with the highest activation values in this dimension of the v ...
