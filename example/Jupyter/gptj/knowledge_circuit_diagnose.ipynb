# %%
from diagnose import diagnose
from dataset_process import knowns, ZsRE, counterfact, pararel, PEP3k, TwentyQ
from models import llama, gptj, gpt2
from methods import KnowledgeCircuits

dataset = knowns.KnownsDataset(loc=knowns.default_loc)
sample = knowns.get_processed_kvs(dataset[0], KnowledgeCircuits.requires_input_keys)

result = diagnose.diagnosing(sample=sample, model_name_or_path=gptj, method=KnowledgeCircuits.name)
print(result)
# Out:
# module 'kv_template' has no attribute 'dataset_info'
# Loaded dataset with 1209 elements
# loading model: /root/autodl-fs/gpt-j-6b
# /root/autodl-fs/gpt-j-6b model loaded
# /root/miniconda3/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Using pad_token, but it is not set yet.
# Loaded pretrained model EleutherAI/gpt-j-6b into HookedTransformer
# clean_subject  (before adjustment): Vinson Massif
# relation: is located in the continent
# clean_label: Antarctica
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:openai._base_client:Retrying request to /chat/completions in 0.442070 seconds
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# corrupted_subject (before adjustment): Makalu
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# corrupted_label: Arctica
# clean (subject+relation): Vinson Massif is located in the continent
# corrupted (subject+relation): Makalu is located in the continent
# 100%|██████████| 316723/316723 [00:00<00:00, 396077.41it/s]
# None
# {'output': 'Antarctica', 'image': [{'image_name': 'Knowledge Circuit Graph', 'image_path': '/root/interpret-lm/util/tmp/f5i6ovg0.png', 'image_des': 'The Knowledge Circuit Graph is used to visualize the key nodes and edges when a model processes a specific task. In the graph, nodes represent different computing units in the model (such as attention heads and MLP nodes), and edges represent the connections between these nodes and their importance (indicated by the thickness of the edges). The thickness reflects the weight or score of the edges, helping to identify the most important paths and connections in the model. When connected to attention heads: Edges of the q type will be purple. Edges of the k type will be green. Edges of the v type will be blue. Such color differentiation is used to visualize different parts of the attention mechanism. When connected to MLP nodes: Colors are used to represent the difference between positive and negative weights. Red represents negative weights, while black represents positive weights.', 'image_res': 'The graph displays the key nodes and edges in the model when processing input data. After filtering operations, only the edges with the highest scores are retained.'}], 'origin_data': {'Important Nodes and Edges for Knowledge Circuit Graph': {'cfg': {'n_layers': 28, 'n_heads': 16, 'parallel_attn_mlp': True}, 'nodes': {'input': True, 'a0.h0': True, 'a0.h2': True, 'a0.h4': True, 'a0.h6': True, 'a0.h7': True, 'a0.h8': True, 'a0.h9': True, 'a0.h10': True, 'a0.h13': True, 'a0.h14': True, 'a0.h15': True, 'm0': True, 'a1.h0': True, 'a1.h2': True, 'a1.h3': True, 'a1.h6': True, 'a1.h8': True, 'a1.h10': True, 'a1.h13': True, 'a1.h14': True, 'm1': True, 'a2.h0': True, 'a2.h1': True, 'a2.h2': True, 'a2.h5': True, 'a2.h7': True, 'a2.h8': True, 'a2.h10': True, 'a2.h11': True, 'a2.h13': True, 'm2': True, 'a3.h0': True, 'a3.h1': True, 'a3.h3': True, 'a3.h7': True, 'm3': True, 'a4.h11': True, 'a4.h15': True, 'm4': True, 'a5.h2': True, 'a5.h6': True, 'm5': True, 'a6.h5': True, 'a6.h11': True, 'm6': True, 'm7': True, 'm8': True, 'm9': True, 'a10.h3': True, 'm10': True, 'a11.h8': True, 'a11.h11': True, 'm11': True, 'a12.h7': True, 'a12.h11': True, 'm12': True, 'a13.h15': True, 'm13': True, 'a14.h9': True, 'a14.h12': True, 'm14': True, 'm15': True, 'a16.h0': True, 'a16.h10': True, 'm16': True, 'm17': True, 'm18': True, 'a19.h12': True, 'a19.h14': True, 'm19': True, 'a20.h14': True, 'm20': True, 'm21': True, 'm22': True, 'm23': True, 'a24.h10': True, 'a25.h13': True, 'm25': True, 'a26.h15': True, 'logits': True}, 'edges': {'input->a0.h0<q>': {'score': 0.6624670028686523, 'in_graph': True}, 'input->a0.h0<k>': {'score': -0.13249512016773224, 'in_graph': True}, 'input->a0.h0<v>': {'score': 0.4999331533908844, 'in_graph': True}, 'input->a0.h2<q>': {'score': 0.090070940554142, 'in_graph': True}, 'input->a0.h4<q>': {'score': 0.0526227168738842, 'in_graph': True}, 'input->a0.h4<v>': {'score': 0.11645247042179108, 'in_graph': True}, 'input->a0.h6<v>': {'score': 0.2797931134700775, 'in_graph': True}, 'input->a0.h7<v>': {'score': -0.3586192727088928, 'in_graph': True}, 'input->a0.h8<k>': {'score': 0.05766191706061363, 'in_graph': True}, 'input->a0.h8<v>': {'score': -0.17851471900939941, 'in_graph': True}, 'input->a0.h9<k>': {'score': -0.10015714168548584, 'in_graph': True}, 'input->a0.h9<v>': {'score': -0.2213992476463318, 'in_graph': True}, 'input->a0.h10<q>': {'score': -0.0750630721449852, 'in_graph': True}, 'input->a0.h10<v>': {'score': -0.0646190345287323, 'in_graph': True}, 'input->a0.h13<q>': {'score': 0.20644496381282806, 'in_graph': True}, 'input->a0.h13<k>': {'score': 0.2891409695148468, 'in_graph': True}, 'input->a0.h13<v>': {'score': 0.840480387210846, 'in_graph': True}, 'input->a0.h14<q>': {'score': 0.07829491794109344, 'in_graph': True}, 'input->a0.h14<v>': {'score': 0.15490266680717468, 'in_graph': True}, 'input->a0.h15<q>': {'score': -0.09500783681869507, 'in_graph': True}, 'input->a0.h15<k>': {'score': -0 ...
