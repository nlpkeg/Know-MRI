# %%
from diagnose import diagnose
from dataset_process import knowns, ZsRE, counterfact, pararel, PEP3k, TwentyQ
from models import llama, gptj, gpt2, qwen, bert, t5, chatglm2, internlm, baichuan
from methods import EmbeddingProject

dataset = knowns.KnownsDataset(loc=knowns.default_loc)
sample = knowns.get_processed_kvs(dataset[0], EmbeddingProject.requires_input_keys)

result = diagnose.diagnosing(sample=sample, model_name_or_path=gptj, method=EmbeddingProject.name)
print(result)
# Out:
# module 'kv_template' has no attribute 'dataset_info'
# Loaded dataset with 1209 elements
# loading model: /root/autodl-fs/gpt-j-6b
# INFO:accelerate.utils.modeling:We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# /root/autodl-fs/gpt-j-6b model loaded
# {'origin_data': [{'V': [-5.43720817565918, -11.429949760437012, -16.730134963989258], 'inson': [-14.406861305236816, -18.10675621032715, 102.84642028808594], ' Mass': [83.23873901367188, 13.467909812927246, 4.208675861358643], 'if': [-11.861207008361816, -24.625598907470703, -15.707574844360352], ' is': [-9.360243797302246, -9.771416664123535, -4.796963691711426], ' located': [-9.311957359313965, -11.744796752929688, -20.346036911010742], ' in': [-7.308577060699463, -5.840567111968994, -2.6478285789489746], ' the': [-6.8841872215271, -7.157217979431152, -0.20543605089187622], ' continent': [-27.429384231567383, 85.7657241821289, -0.11412978917360306], ' of': [-9.2311372756958, -7.67129373550415, -3.66605544090271]}, {'ĠV': [-5.750799655914307, -13.23086929321289, -18.528888702392578], '<|extratoken_115|>': [-5.829131126403809, -3.990788459777832, -0.6481170058250427], 'ĠexternalToEVAOnly': [-5.813769817352295, -4.029502868652344, -0.07964121550321579], 'ĠguiActiveUn': [-5.819960594177246, -3.784402847290039, -0.2701319456100464], 'Mass': [81.82274627685547, 11.199759483337402, 4.9759135246276855], 'Ġmass': [71.67144775390625, 8.62656307220459, -2.0290563106536865], 'Ġif': [-10.310446739196777, -18.92589569091797, -13.363463401794434], 'rawdownloadcloneembedreportprint': [-5.699618816375732, -4.20222806930542, -0.7901312708854675], 'Ġare': [-10.121894836425781, -10.320425033569336, -4.7958526611328125], 'Ġwas': [-8.616256713867188, -9.117157936096191, -5.00392484664917], 'Ġdavidjl': [-5.818927764892578, -3.9683547019958496, -0.6698627471923828], '<|extratoken_63|>': [-5.853368282318115, -4.0208868980407715, -0.601836085319519], 'ĠunfocusedRange': [-5.713082313537598, -3.9915919303894043, -0.38185763359069824], '<|extratoken_69|>': [-5.803922176361084, -3.9977641105651855, -0.6838482618331909], '<|extratoken_119|>': [-5.835829257965088, -4.023117542266846, -0.6363361477851868], '<|extratoken_43|>': [-5.861286640167236, -3.97428560256958, -0.60832679271698], 'ĠContinent': [-25.259733200073242, 80.61766052246094, 3.0568089485168457], '<|extratoken_85|>': [-5.802075386047363, -3.858424663543701, -0.5033498406410217], '<|extratoken_112|>': [-5.727717399597168, -3.918545722961426, -0.7134184837341309], 'StreamerBot': [-5.86433744430542, -3.975802421569824, -0.5656116008758545]}], 'image': [{'image_name': 'pca', 'image_path': '/root/interpret-lm/util/tmp/method_pca_token_nums3_top_k2_num_neighbors3_dim3_2_o1y_nh.png', 'image_des': 'Dimension reduction results of embeddings of the original tokens and the top_k tokens with the largest similarity in vocabulary'}], 'table': [{'table_name': 'Prompt Tokens and Their Top-K Similar Tokens', 'table_list': [{'Original Token': 'V', 'Similar Tokens': ['ĠV', '<|extratoken_115|>']}, {'Original Token': 'inson', 'Similar Tokens': ['ĠexternalToEVAOnly', 'ĠguiActiveUn']}, {'Original Token': ' Mass', 'Similar Tokens': ['Mass', 'Ġmass']}], 'tabel_des': '', 'tabel_res': ''}], 'result_des': ''}
