# %%
from diagnose import diagnose
from dataset_process import knowns, ZsRE, counterfact, pararel, PEP3k, TwentyQ
from models import llama, gptj, gpt2
from methods import KnowledgeCircuits

dataset = knowns.KnownsDataset(loc=knowns.default_loc)
sample = knowns.get_processed_kvs(dataset[0], KnowledgeCircuits.requires_input_keys)

result = diagnose.diagnosing(sample=sample, model_name_or_path=llama, method=KnowledgeCircuits.name)
print(result)
# Out:
# module 'kv_template' has no attribute 'dataset_info'
# Loaded dataset with 1209 elements
# loading model: /root/autodl-fs/llama-2-7b-hf
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /root/autodl-fs/llama-2-7b-hf model loaded
# /root/miniconda3/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Using pad_token, but it is not set yet.
# Loaded pretrained model meta-llama/Llama-2-7b-hf into HookedTransformer
# clean_subject  (before adjustment): Vinson Massif
# relation: is located in the continent
# clean_label: Antarctica
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# corrupted_subject (before adjustment): Kilimanjaro
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# corrupted_label: Polarica
# clean (subject+relation): Vinson Massif is located in the continent
# corrupted (subject+relation): Kilimanjaro is located in the continent
# 100%|██████████| 1592881/1592881 [00:03<00:00, 418534.67it/s]
# None
# {'output': 'Antarctica', 'image': [{'image_name': 'Knowledge Circuit Graph', 'image_path': '/root/interpret-lm/util/tmp/q3a8z79w.png', 'image_des': 'The Knowledge Circuit Graph is used to visualize the key nodes and edges when a model processes a specific task. In the graph, nodes represent different computing units in the model (such as attention heads and MLP nodes), and edges represent the connections between these nodes and their importance (indicated by the thickness of the edges). The thickness reflects the weight or score of the edges, helping to identify the most important paths and connections in the model. When connected to attention heads: Edges of the q type will be purple. Edges of the k type will be green. Edges of the v type will be blue. Such color differentiation is used to visualize different parts of the attention mechanism. When connected to MLP nodes: Colors are used to represent the difference between positive and negative weights. Red represents negative weights, while black represents positive weights.', 'image_res': 'The graph displays the key nodes and edges in the model when processing input data. After filtering operations, only the edges with the highest scores are retained.'}], 'origin_data': {'Important Nodes and Edges for Knowledge Circuit Graph': {'cfg': {'n_layers': 32, 'n_heads': 32, 'parallel_attn_mlp': False}, 'nodes': {'input': True, 'a0.h13': True, 'a0.h25': True, 'm0': True, 'a1.h22': True, 'a1.h24': True, 'a1.h27': True, 'a1.h28': True, 'm1': True, 'a2.h2': True, 'a2.h13': True, 'a2.h17': True, 'm2': True, 'a3.h20': True, 'a3.h23': True, 'm3': True, 'a4.h0': True, 'a4.h3': True, 'a4.h4': True, 'a4.h7': True, 'a4.h17': True, 'a4.h22': True, 'a4.h24': True, 'm4': True, 'a5.h6': True, 'a5.h12': True, 'a5.h17': True, 'a5.h31': True, 'm5': True, 'm6': True, 'a7.h21': True, 'm7': True, 'm8': True, 'm9': True, 'm10': True, 'a11.h28': True, 'm11': True, 'm12': True, 'a13.h24': True, 'm13': True, 'm14': True, 'm15': True, 'a16.h4': True, 'm16': True, 'm17': True, 'm18': True, 'a19.h3': True, 'a19.h30': True, 'm19': True, 'a20.h14': True, 'a20.h18': True, 'm20': True, 'm21': True, 'm22': True, 'm23': True, 'a24.h14': True, 'm24': True, 'a25.h1': True, 'a25.h15': True, 'm25': True, 'm26': True, 'a27.h26': True, 'm27': True, 'a28.h7': True, 'm28': True, 'a29.h9': True, 'm29': True, 'a30.h12': True, 'm30': True, 'm31': True, 'logits': True}, 'edges': {'input->a0.h13<k>': {'score': -0.09601225703954697, 'in_graph': True}, 'input->a0.h13<v>': {'score': 0.10582614690065384, 'in_graph': True}, 'input->a0.h25<k>': {'score': 0.07995867729187012, 'in_graph': True}, 'input->m0': {'score': 1.9411976337432861, 'in_graph': True}, 'a0.h13->m0': {'score': 0.11248692125082016, 'in_graph': True}, 'a0.h25->m0': {'score': 0.0690222978591919, 'in_graph': True}, 'input->a1.h24<q>': {'score': -0.08514214307069778, 'in_graph': True}, 'input->a1.h24<v>': {'score': 0.24702736735343933, 'in_graph': True}, 'input->a1.h27<v>': {'score': 0.4006603956222534, 'in_graph': True}, 'input->a1.h28<v>': {'score': 0.06406161189079285, 'in_graph': True}, 'm0->a1.h22<v>': {'score': 0.11613360047340393, 'in_graph': True}, 'm0->a1.h24<q>': {'score': -0.08892888575792313, 'in_graph': True}, 'm0->a1.h24<v>': {'score': 0.22615531086921692, 'in_graph': True}, 'm0->a1.h27<v>': {'score': 0.32327914237976074, 'in_graph': True}, 'input->m1': {'score': 1.1142456531524658, 'in_graph': True}, 'm0->m1': {'score': 0.46927410364151, 'in_graph': True}, 'a1.h22->m1': {'score': -0.10716173052787781, 'in_graph': True}, 'a1.h24->m1': {'score': -0.06543395668268204, 'in_graph': True}, 'a1.h27->m1': {'score': 0.3354112505912781, 'in_graph': True}, 'a1.h28->m1': {'score': 0.07097182422876358, 'in_graph': True}, 'input->a2.h2<v>': {'score': 0.15807358920574188, 'in_graph': True}, 'input->a2.h13<q>': {'score': 0.05767477676272392, 'in_graph': True}, 'input->a2.h13<k>': {'score': 0.0899491086602211, 'in_graph': True}, 'input->a2.h17<v>': {'score': 0.0848898962140 ...
