# %%
from diagnose import diagnose
from dataset_process import knowns, ZsRE, counterfact, pararel, PEP3k, TwentyQ
from models import llama, gptj, gpt2, qwen, bert, t5, chatglm2, internlm, baichuan
from methods import EmbeddingProject

dataset = knowns.KnownsDataset(loc=knowns.default_loc)
sample = knowns.get_processed_kvs(dataset[0], EmbeddingProject.requires_input_keys)

result = diagnose.diagnosing(sample=sample, model_name_or_path=gpt2, method=EmbeddingProject.name)
print(result)
# Out:
# module 'kv_template' has no attribute 'dataset_info'
# Loaded dataset with 1209 elements
# loading model: /root/autodl-fs/gpt2-xl
# INFO:accelerate.utils.modeling:We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# /root/autodl-fs/gpt2-xl model loaded
# {'origin_data': [{'V': [2.8579180240631104, -9.732110023498535], 'inson': [24.767440795898438, -14.432278633117676], ' Mass': [5.835648536682129, -10.969280242919922], 'if': [7.484426975250244, -10.672785758972168], ' is': [-14.584529876708984, 1.4364229440689087], ' located': [0.3830520510673523, 2.7973320484161377], ' in': [-19.087915420532227, 2.6676554679870605], ' the': [-18.625328063964844, 3.275508165359497], ' continent': [17.792503356933594, 34.618080139160156], ' of': [-15.542746543884277, 2.117218017578125]}, {'ĠV': [-8.834375381469727, -0.919454038143158], 'F': [3.669750928878784, -10.480950355529785], 'enson': [23.795900344848633, -12.03783130645752], 'ison': [16.64780616760254, -16.20292091369629], 'Mass': [17.98478126525879, -18.019807815551758], 'Ġmass': [-0.817039966583252, -6.303868770599365], 'IF': [13.628085136413574, -13.92341423034668], 'If': [7.11700963973999, -9.29317855834961], 'Ġhas': [-11.998856544494629, 0.8274743556976318], 'Ġwas': [-12.27821159362793, 1.0367790460586548], 'Ġsituated': [5.0802903175354, 3.741257905960083], 'ĠLocated': [14.941368103027344, 1.3090167045593262], 'Ġon': [-16.899049758911133, 1.891393780708313], 'Ġat': [-16.55029296875, 1.7722280025482178], 'Ġa': [-18.260892868041992, 3.0403947830200195], 'Ġan': [-14.547139167785645, 2.2685458660125732], 'ĠContinent': [24.303667068481445, 36.490718841552734], 'Ġcontinents': [19.087718963623047, 29.556516647338867], 'Ġin': [-19.087915420532227, 2.6676554679870605], ',': [-18.263086318969727, 1.4736813306808472]}], 'image': [{'image_name': 'pca', 'image_path': '/root/interpret-lm/util/tmp/method_pca_token_nums3_top_k2_num_neighbors3_dim2_gn_dx7ms.png', 'image_des': 'Dimension reduction results of embeddings of the original tokens and the top_k tokens with the largest similarity in vocabulary'}], 'table': [{'table_name': 'Prompt Tokens and Their Top-K Similar Tokens', 'table_list': [{'Original Token': 'V', 'Similar Tokens': ['ĠV', 'F']}, {'Original Token': 'inson', 'Similar Tokens': ['enson', 'ison']}, {'Original Token': ' Mass', 'Similar Tokens': ['Mass', 'Ġmass']}], 'tabel_des': '', 'tabel_res': ''}], 'result_des': ''}
