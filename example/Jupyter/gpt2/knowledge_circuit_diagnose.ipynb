# %%
from diagnose import diagnose
from dataset_process import knowns, ZsRE, counterfact, pararel, PEP3k, TwentyQ
from models import llama, gptj, gpt2
from methods import KnowledgeCircuits

dataset = knowns.KnownsDataset(loc=knowns.default_loc)
sample = knowns.get_processed_kvs(dataset[0], KnowledgeCircuits.requires_input_keys)

result = diagnose.diagnosing(sample=sample, model_name_or_path=gpt2, method=KnowledgeCircuits.name)
print(result)
# Out:
# module 'kv_template' has no attribute 'dataset_info'
# Loaded dataset with 1209 elements
# loading model: /root/autodl-fs/gpt2-xl
# /root/autodl-fs/gpt2-xl model loaded
# /root/miniconda3/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Using pad_token, but it is not set yet.
# Loaded pretrained model gpt2-xl into HookedTransformer
# clean_subject  (before adjustment): Vinson Massif
# relation: is located in the continent
# clean_label: Antarctica
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# corrupted_subject (before adjustment): Makalu
# INFO:httpx:HTTP Request: POST https://api.vveai.com/v1/chat/completions "HTTP/1.1 200 OK"
# corrupted_label: Arctilora
# clean (subject+relation): Vinson Massif is located in the continent
# corrupted (subject+relation): Makalu is located in the continent
# 100%|██████████| 2235025/2235025 [00:05<00:00, 419315.21it/s]
# None
# {'output': 'Antarctica', 'image': [{'image_name': 'Knowledge Circuit Graph', 'image_path': '/root/interpret-lm/util/tmp/_b9x_z7c.png', 'image_des': 'The Knowledge Circuit Graph is used to visualize the key nodes and edges when a model processes a specific task. In the graph, nodes represent different computing units in the model (such as attention heads and MLP nodes), and edges represent the connections between these nodes and their importance (indicated by the thickness of the edges). The thickness reflects the weight or score of the edges, helping to identify the most important paths and connections in the model. When connected to attention heads: Edges of the q type will be purple. Edges of the k type will be green. Edges of the v type will be blue. Such color differentiation is used to visualize different parts of the attention mechanism. When connected to MLP nodes: Colors are used to represent the difference between positive and negative weights. Red represents negative weights, while black represents positive weights.', 'image_res': 'The graph displays the key nodes and edges in the model when processing input data. After filtering operations, only the edges with the highest scores are retained.'}], 'origin_data': {'Important Nodes and Edges for Knowledge Circuit Graph': {'cfg': {'n_layers': 48, 'n_heads': 25, 'parallel_attn_mlp': False}, 'nodes': {'input': True, 'a0.h9': True, 'a0.h22': True, 'm0': True, 'a1.h9': True, 'a1.h17': True, 'm1': True, 'a2.h12': True, 'm2': True, 'a3.h5': True, 'm3': True, 'a4.h15': True, 'a4.h21': True, 'm4': True, 'a5.h9': True, 'a5.h22': True, 'm5': True, 'a6.h1': True, 'm6': True, 'a7.h12': True, 'a7.h19': True, 'm7': True, 'a8.h2': True, 'a8.h6': True, 'a8.h10': True, 'm8': True, 'a9.h7': True, 'a9.h10': True, 'm9': True, 'a10.h15': True, 'm10': True, 'a11.h2': True, 'm11': True, 'a12.h21': True, 'm12': True, 'a13.h12': True, 'm13': True, 'a14.h10': True, 'a14.h12': True, 'm14': True, 'm15': True, 'a16.h5': True, 'm16': True, 'a17.h9': True, 'm17': True, 'm18': True, 'm19': True, 'm20': True, 'm21': True, 'm22': True, 'm23': True, 'm24': True, 'a25.h4': True, 'm25': True, 'm26': True, 'm27': True, 'm28': True, 'm29': True, 'a30.h8': True, 'm30': True, 'm31': True, 'm32': True, 'm34': True, 'm36': True, 'm37': True, 'm38': True, 'm39': True, 'm40': True, 'm41': True, 'm42': True, 'a43.h5': True, 'm43': True, 'm44': True, 'm45': True, 'm46': True, 'm47': True, 'logits': True}, 'edges': {'input->a0.h9<k>': {'score': 0.03276514261960983, 'in_graph': True}, 'input->a0.h9<v>': {'score': 0.021444912999868393, 'in_graph': True}, 'input->a0.h22<v>': {'score': 0.024422604590654373, 'in_graph': True}, 'input->m0': {'score': 0.7074527740478516, 'in_graph': True}, 'a0.h9->m0': {'score': 0.024976510554552078, 'in_graph': True}, 'a0.h22->m0': {'score': 0.023881400004029274, 'in_graph': True}, 'm0->a1.h9<q>': {'score': 0.02262941561639309, 'in_graph': True}, 'm0->a1.h9<v>': {'score': -0.04289690777659416, 'in_graph': True}, 'm0->a1.h17<q>': {'score': -0.07039955258369446, 'in_graph': True}, 'm0->m1': {'score': 0.13624048233032227, 'in_graph': True}, 'm0->a2.h12<v>': {'score': 0.0430174395442009, 'in_graph': True}, 'm1->a2.h12<v>': {'score': 0.024175602942705154, 'in_graph': True}, 'm0->m2': {'score': 0.6913728713989258, 'in_graph': True}, 'm1->m2': {'score': 0.29771357774734497, 'in_graph': True}, 'm0->a3.h5<v>': {'score': 0.020636430010199547, 'in_graph': True}, 'm0->m3': {'score': -0.08936277776956558, 'in_graph': True}, 'm2->m3': {'score': 0.056073807179927826, 'in_graph': True}, 'm0->a4.h15<v>': {'score': 0.023792658001184464, 'in_graph': True}, 'm0->a4.h21<v>': {'score': 0.04651166871190071, 'in_graph': True}, 'm1->a4.h21<v>': {'score': 0.02136337198317051, 'in_graph': True}, 'm0->m4': {'score': -0.026065638288855553, 'in_graph': True}, 'a1.h9->m4': {'score': 0.03251425549387932, 'in_graph': True}, 'm2->m4': {'score': -0.027707213535904884, 'in_graph': True}, 'm3->m4': {'score': -0.04660059884190 ...
