# %%
from diagnose import diagnose
from dataset_process import ZsRE
from models import llama, gptj, gpt2, bert, t5, qwen, chatglm2
from methods import SPINE

dataset = ZsRE.ZsREDataset(loc=ZsRE.default_loc)
sample = ZsRE.get_processed_kvs(dataset[0], SPINE.requires_input_keys)
result = diagnose.diagnosing(sample=sample, model_name_or_path=gpt2, method=SPINE.name)

print(result)
# Out:
# module 'kv_template' has no attribute 'dataset_info'
# Loaded dataset with 1301 elements
# loading model: /root/autodl-fs/gpt2-xl
# INFO:accelerate.utils.modeling:We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# /root/autodl-fs/gpt2-xl model loaded
# /root/interpret-lm/methods/SPINE/SPINE_main.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(embedding).to(dtype)
# {'origin_data': {'sample_tokens': ['Which', 'family', 'does', 'Ep', 'asp', 'id', 'oc', 'er', 'as', 'bel', 'ong', 'to', '?'], 'topk_embeddings': [[[4309, 0.05592988803982735], [1086, 0.05485645309090614], [1168, 0.05047519877552986], [1992, 0.047173742204904556], [5347, 0.044982798397541046]], [[3559, 0.06886524707078934], [3540, 0.06439349055290222], [2452, 0.0636460930109024], [2575, 0.05954164266586304], [3084, 0.057442426681518555]], [[6075, 0.0625067874789238], [5257, 0.05200982093811035], [3095, 0.048671409487724304], [1918, 0.04856490716338158], [3988, 0.0447908453643322]], [[5168, 0.08829590678215027], [5973, 0.06598741561174393], [5603, 0.06435569375753403], [5561, 0.06305002421140671], [5642, 0.06285227835178375]], [[5579, 0.0837441235780716], [2906, 0.0798308253288269], [4554, 0.0755140483379364], [4569, 0.07435070723295212], [1918, 0.06946936994791031]], [[1076, 0.07868808507919312], [5914, 0.06927473843097687], [3072, 0.06308864057064056], [3946, 0.0607946403324604], [21, 0.058633461594581604]], [[4656, 0.09548390656709671], [3644, 0.0728050097823143], [5660, 0.06833215802907944], [1215, 0.06832238286733627], [1489, 0.06830964237451553]], [[1088, 0.06141567975282669], [1989, 0.05777210369706154], [1776, 0.05604653060436249], [5976, 0.05446995049715042], [200, 0.05306084454059601]], [[6081, 0.062319353222846985], [2329, 0.05135638266801834], [5719, 0.04604652151465416], [3930, 0.044863585382699966], [1978, 0.04419814795255661]], [[1708, 0.08104132115840912], [4469, 0.07311632484197617], [3517, 0.0705568790435791], [2273, 0.06291922181844711], [3928, 0.061741966754198074]], [[5618, 0.08098272979259491], [2595, 0.07098615914583206], [1852, 0.06756699830293655], [4140, 0.0660986602306366], [3418, 0.06473508477210999]], [[5630, 0.06980737298727036], [4469, 0.056983597576618195], [3561, 0.050229720771312714], [3243, 0.05010304972529411], [2171, 0.0455612875521183]], [[3440, 0.051180850714445114], [461, 0.04640548303723335], [2122, 0.04515361040830612], [5460, 0.03744608908891678], [7, 0.03719521313905716]]]}, 'table': [{'table_name': ' token Which', 'table_list': [{'dimension': 4309, 'activation values': 0.05592988803982735, 'The tokens with the highest activation values in this dimension of the vocabulary': ['ü', 'iz', '6', '."', 'ĠFlor']}, {'dimension': 1086, 'activation values': 0.05485645309090614, 'The tokens with the highest activation values in this dimension of the vocabulary': ['oo', 'Ġtwo', 'Ġwouldn', 'Ġmanner', 'ĠNor']}, {'dimension': 1168, 'activation values': 0.05047519877552986, 'The tokens with the highest activation values in this dimension of the vocabulary': ['Ġnormal', 'ĠBl', 'Ġtrans', 'Ġhousing', 'Ġserved']}, {'dimension': 1992, 'activation values': 0.047173742204904556, 'The tokens with the highest activation values in this dimension of the vocabulary': ['Ġqual', 'Ġfeet', 'ĠLee', 'ients', 'Ġpatients']}, {'dimension': 5347, 'activation values': 0.044982798397541046, 'The tokens with the highest activation values in this dimension of the vocabulary': ['Ġdepend', 'oe', 'rem', 'Ġleading', 'Ġimages']}], 'table_des': 'Each row represents one of the top-k activation values along with its corresponding dimensional index and the several words from the vocabulary that have the highest activation values in this dimension', 'table_res': ''}, {'table_name': ' token family', 'table_list': [{'dimension': 3559, 'activation values': 0.06886524707078934, 'The tokens with the highest activation values in this dimension of the vocabulary': ['23', 'Ġknew', 'ĠFe', 'Ġpick', 'ĠWith']}, {'dimension': 3540, 'activation values': 0.06439349055290222, 'The tokens with the highest activation values in this dimension of the vocabulary': ['amin', 'Ġemploy', 'arrow', 'Ġcharact', 'Ġsleep']}, {'dimension': 2452, 'activation values': 0.0636460930109024, 'The tokens with the highest activation values in this dimension of the vocabulary': ['Ġultimately', 'ĠOb', 'ards', 'ĠFlor', 'è']}, {'dimension': 2575, 'activation values': 0.0595416426 ...
