# %%
from diagnose import diagnose
from dataset_process import ZsRE
from models import llama, gptj, gpt2, bert, t5, qwen, chatglm2
from methods import SPINE

dataset = ZsRE.ZsREDataset(loc=ZsRE.default_loc)
sample = ZsRE.get_processed_kvs(dataset[0], SPINE.requires_input_keys)
result = diagnose.diagnosing(sample=sample, model_name_or_path=bert, method=SPINE.name)

print(result)
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# module 'kv_template' has no attribute 'dataset_info'
# Loaded dataset with 1301 elements
# loading model: /root/autodl-fs/bert
# Some weights of the model checkpoint at /root/autodl-fs/bert were not used when initializing BertLMHeadModel: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertLMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertLMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Using eos_token, but it is not set yet.
# /root/autodl-fs/bert model loaded
# /root/interpret-lm/methods/SPINE/SPINE_main.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(embedding).to(dtype)
# {'origin_data': {'sample_tokens': ['which', 'family', 'does', 'epa', '##sp', '##ido', '##cera', '##s', 'belong', 'to', '?'], 'topk_embeddings': [[[1577, 0.04457351192831993], [2058, 0.03689611330628395], [2889, 0.036447908729314804], [2573, 0.03470182791352272], [509, 0.03455441817641258]], [[2740, 0.060765206813812256], [661, 0.060397736728191376], [192, 0.05189741030335426], [186, 0.04455050081014633], [1550, 0.044469788670539856]], [[879, 0.05494554713368416], [341, 0.04762766510248184], [1357, 0.040148042142391205], [2418, 0.038786787539720535], [2530, 0.03794276714324951]], [[2929, 0.055705782026052475], [2530, 0.05274295061826706], [2604, 0.04585947468876839], [1287, 0.04551253095269203], [2740, 0.03880587965250015]], [[1357, 0.07390361279249191], [151, 0.05842316895723343], [1840, 0.046763017773628235], [1862, 0.046088408678770065], [715, 0.04459850490093231]], [[2530, 0.0620562918484211], [2008, 0.05961412936449051], [1624, 0.055986810475587845], [2418, 0.048213083297014236], [752, 0.047335103154182434]], [[2985, 0.0564391165971756], [1728, 0.04676593840122223], [2848, 0.04479435458779335], [161, 0.04474538937211037], [2640, 0.039878107607364655]], [[441, 0.0422343909740448], [2018, 0.038941219449043274], [302, 0.03800533339381218], [2180, 0.0362742580473423], [2383, 0.03526291623711586]], [[1265, 0.0670965388417244], [2123, 0.03759654611349106], [2250, 0.035457100719213486], [1293, 0.03389165550470352], [2838, 0.031732168048620224]], [[1431, 0.046583835035562515], [995, 0.04508131369948387], [545, 0.04044278711080551], [2321, 0.039959680289030075], [2160, 0.03682560473680496]], [[1789, 0.061179764568805695], [259, 0.04424186423420906], [2617, 0.040406011044979095], [2395, 0.038877371698617935], [871, 0.0369451679289341]]]}, 'table': [{'table_name': ' token which', 'table_list': [{'dimension': 1577, 'activation values': 0.04457351192831993, 'The tokens with the highest activation values in this dimension of the vocabulary': ['western', '[unused156]', '[unused549]', 'art', 'what']}, {'dimension': 2058, 'activation values': 0.03689611330628395, 'The tokens with the highest activation values in this dimension of the vocabulary': ['ₒ', 'ා', 'western', '[unused924]', '間']}, {'dimension': 2889, 'activation values': 0.036447908729314804, 'The tokens with the highest activation values in this dimension of the vocabulary': ['movement', '20', '[unused352]', '[unused282]', 'ছ']}, {'dimension': 2573, 'activation values': 0.03470182791352272, 'The tokens with the highest activation values in this dimension of the vocabulary': ['without', 'এ', '歌', '[unused577]', '[unused9]']}, {'dimension': 509, 'activation values': 0.03455441817641258, 'The tokens with the highest activation values in this dimension of the vocabulary': ['air', '[unused427]', 'ছ', 'western', 'น']}], 'table_des': 'Each row represents one of the top-k activation values along with its corresponding dimensional index and the several words from the vocabulary that have the highest activation values in this dimension', 'table_res': ''}, {'table_name': ' token family', 'table_list': [{'dimension': 2740, 'activation values': 0.060765206813812256, 'The tokens with the highest activation values in this dimension of the vocabulary': ['@', '⊗', '[unused493]', 'european', '竹']}, {'dimension': 661, 'activation values': 0.060397736728191376, 'The tokens with the highest activation values in this dimension of the vocabulary': ['air', '[unused427]', 'ছ', 'น', 'western']}, {'dimension': 192, 'activation values': 0.05189741030335426, 'The tokens with the highest activation values in this dimension of the vocabulary': ['air', '[unused427]', 'ছ', 'น', 'western']}, {'dimension': 186, 'activation values': 0.04455050081014633, 'The tokens with the highest activation values in this dimension of the vocabulary': ['air', 'ছ', '[unused427]', 'western', '[unused13]']}, {'dimension': 1550, 'activation values': 0.044469788670539856, 'The tokens with the highest activation values in this dimensio ...
