# %%
from diagnose import diagnose
from dataset_process import ZsRE
from models import llama, gptj, gpt2, bert, t5, qwen, chatglm2
from methods import SPINE

dataset = ZsRE.ZsREDataset(loc=ZsRE.default_loc)
sample = ZsRE.get_processed_kvs(dataset[0], SPINE.requires_input_keys)
result = diagnose.diagnosing(sample=sample, model_name_or_path=t5, method=SPINE.name)

print(result)
# Out:
# module 'kv_template' has no attribute 'dataset_info'
# Loaded dataset with 1301 elements
# loading model: /root/autodl-fs/t5
# INFO:accelerate.utils.modeling:We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# /root/autodl-fs/t5 model loaded
# /root/interpret-lm/methods/SPINE/SPINE_main.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(embedding).to(dtype)
# {'origin_data': {'sample_tokens': ['▁Which', '</s>', '▁family', '▁does', '▁Ep', 'a', 'spi', 'doc', 'era', 's', '▁belong', '▁to', '?'], 'topk_embeddings': [[[2, 1.0], [0, 1.0], [4, 1.0], [7, 1.0], [5, 1.0]], [[1, 1.0], [0, 1.0], [5, 1.0], [15, 1.0], [9, 1.0]], [[2, 1.0], [0, 1.0], [3, 1.0], [5, 1.0], [4, 1.0]], [[6, 1.0], [0, 1.0], [7, 1.0], [11, 1.0], [8, 1.0]], [[5, 1.0], [0, 1.0], [6, 1.0], [9, 1.0], [7, 1.0]], [[4, 1.0], [1, 1.0], [8, 1.0], [11, 1.0], [9, 1.0]], [[4, 1.0], [3, 1.0], [6, 1.0], [10, 1.0], [8, 1.0]], [[5, 1.0], [0, 1.0], [14, 1.0], [18, 1.0], [15, 1.0]], [[4, 1.0], [0, 1.0], [6, 1.0], [11, 1.0], [7, 1.0]], [[8, 1.0], [4, 1.0], [11, 1.0], [13, 1.0], [12, 1.0]], [[2, 1.0], [0, 1.0], [3, 1.0], [6, 1.0], [5, 1.0]], [[8, 1.0], [0, 1.0], [12, 1.0], [25, 1.0], [23, 1.0]], [[3, 1.0], [0, 1.0], [6, 1.0], [11, 1.0], [10, 1.0]]]}, 'table': [{'table_name': ' token ▁Which', 'table_list': [{'dimension': 2, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['a', '</s>', '▁of', '▁de', '▁is']}, {'dimension': 0, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['</s>', '<pad>', '<unk>', 's', '.']}, {'dimension': 4, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': [',', 'X', 's', '▁to', '▁the']}, {'dimension': 7, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['▁the', 'X', '▁and', '▁of', '▁to']}, {'dimension': 5, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['s', '<pad>', ':', '▁de', 'e']}], 'table_des': 'Each row represents one of the top-k activation values along with its corresponding dimensional index and the several words from the vocabulary that have the highest activation values in this dimension', 'table_res': ''}, {'table_name': ' token </s>', 'table_list': [{'dimension': 1, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['</s>', '<pad>', '.', 'e', 'a']}, {'dimension': 0, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['</s>', '<pad>', '<unk>', 's', '.']}, {'dimension': 5, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['s', '<pad>', ':', '▁de', 'e']}, {'dimension': 15, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['▁the', ',', '▁and', '▁of', '▁to']}, {'dimension': 9, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['X', '</s>', '▁the', '▁and', 'a']}], 'table_des': 'Each row represents one of the top-k activation values along with its corresponding dimensional index and the several words from the vocabulary that have the highest activation values in this dimension', 'table_res': ''}, {'table_name': ' token ▁family', 'table_list': [{'dimension': 2, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['a', '</s>', '▁of', '▁de', '▁is']}, {'dimension': 0, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['</s>', '<pad>', '<unk>', 's', '.']}, {'dimension': 3, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['X', '▁', '.', 'a', ',']}, {'dimension': 5, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': ['s', '<pad>', ':', '▁de', 'e']}, {'dimension': 4, 'activation values': 1.0, 'The tokens with the highest activation values in this dimension of the vocabulary': [',', 'X', 's', '▁to', '▁the']}], 'table_des': 'Each row represents one of the top-k activation values a ...
