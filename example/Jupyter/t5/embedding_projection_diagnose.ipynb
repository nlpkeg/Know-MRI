# %%
from diagnose import diagnose
from dataset_process import knowns, ZsRE, counterfact, pararel, PEP3k, TwentyQ
from models import llama, gptj, gpt2, qwen, bert, t5, chatglm2, internlm, baichuan
from methods import EmbeddingProject

dataset = knowns.KnownsDataset(loc=knowns.default_loc)
sample = knowns.get_processed_kvs(dataset[0], EmbeddingProject.requires_input_keys)

result = diagnose.diagnosing(sample=sample, model_name_or_path=t5, method=EmbeddingProject.name)
print(result)
# Out:
# module 'kv_template' has no attribute 'dataset_info'
# Loaded dataset with 1209 elements
# loading model: /root/autodl-fs/t5
# INFO:accelerate.utils.modeling:We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# /root/autodl-fs/t5 model loaded
# {'origin_data': [{'Vin': [-26.297204971313477, -11.739282608032227, 22.017742156982422], 'son': [-4.641233444213867, -5.377961158752441, -11.752107620239258], 'Mass': [-3.0658693313598633, 30.067190170288086, 9.753950119018555], 'if': [-1.147425889968872, -1.0874207019805908, -7.103377819061279], 'is': [-0.7276285886764526, -0.5913311243057251, -4.408031463623047], 'located': [2.988621950149536, 0.710256040096283, -8.752274513244629], 'in': [-1.1298809051513672, -0.6697732210159302, -2.898953914642334], 'the': [0.005528612527996302, -0.10155230760574341, -3.6438562870025635], 'continent': [26.506267547607422, -12.406730651855469, 13.766524314880371], 'of': [0.2422393411397934, -0.7358880043029785, -3.6044325828552246], '</s>': [0.2399246096611023, -1.0617830753326416, -4.240085601806641]}, {'▁vin': [-24.920103073120117, -11.13051986694336, 21.109020233154297], '▁vine': [-15.331693649291992, -13.008832931518555, 21.623748779296875], 'SON': [-3.2054598331451416, -7.467207908630371, -12.119425773620605], 'sons': [-4.412555694580078, -5.158452987670898, -11.130777359008789], '▁mass': [0.09014295786619186, 26.954193115234375, 10.315401077270508], 'Mass': [0.42232152819633484, 33.84520721435547, 11.239108085632324], '▁If': [-1.8868402242660522, -1.6801912784576416, -7.327949047088623], 'If': [-2.460982084274292, -0.8019633889198303, -9.07387638092041], '▁are': [0.06044132262468338, -0.8577037453651428, -4.732477188110352], '▁was': [-0.8840808868408203, 0.6530352234840393, -3.722592353820801], 'Located': [1.8913331031799316, 2.0083444118499756, -9.068184852600098], '▁situated': [4.369589328765869, 0.1447608768939972, -7.336789608001709], '▁In': [-2.4588208198547363, -1.1072874069213867, -3.2092843055725098], '▁IN': [-2.5614020824432373, -1.1164265871047974, -2.694305658340454], '▁The': [-0.26348456740379333, 0.026818424463272095, -4.673671722412109], 'The': [-0.13551969826221466, 0.4851694107055664, -6.002845764160156], 'continent': [29.895606994628906, -13.053473472595215, 15.763988494873047], '▁continental': [29.908069610595703, -2.7267837524414062, 16.244348526000977], '▁and': [0.23767495155334473, -0.27887997031211853, -2.696758985519409], '▁Of': [0.11679334938526154, -1.7979795932769775, -5.592262268066406], '.': [-0.48173245787620544, -0.5937857627868652, -3.3324027061462402], ').': [-0.962632954120636, -0.3437733054161072, -2.7171077728271484]}], 'image': [{'image_name': 'pca', 'image_path': '/root/interpret-lm/util/tmp/method_pca_token_nums3_top_k2_num_neighbors3_dim3_sgmgwutk.png', 'image_des': 'Dimension reduction results of embeddings of the original tokens and the top_k tokens with the largest similarity in vocabulary'}], 'table': [{'table_name': 'Prompt Tokens and Their Top-K Similar Tokens', 'table_list': [{'Original Token': 'Vin', 'Similar Tokens': ['▁vin', '▁vine']}, {'Original Token': 'son', 'Similar Tokens': ['SON', 'sons']}, {'Original Token': 'Mass', 'Similar Tokens': ['▁mass', 'Mass']}], 'tabel_des': '', 'tabel_res': ''}], 'result_des': ''}
